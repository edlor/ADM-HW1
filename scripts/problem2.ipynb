# %% [markdown]
# # Problem 2

# %% [markdown]
# ### Birthday Cake Candles
# https://www.hackerrank.com/challenges/birthday-cake-candles

# %%
#!/bin/python3

import math
import os
import random
import re
import sys

#
# Complete the 'birthdayCakeCandles' function below.
#
# The function is expected to return an INTEGER.
# The function accepts INTEGER_ARRAY candles as parameter.
#

def birthdayCakeCandles(candles):
    return(candles.count(max(candles)))

if __name__ == '__main__':
    fptr = open(os.environ['OUTPUT_PATH'], 'w')

    candles_count = int(input().strip())

    candles = list(map(int, input().rstrip().split()))

    result = birthdayCakeCandles(candles)

    fptr.write(str(result) + '\n')

    fptr.close()

# %% [markdown]
# ### Number Line Jumps
# https://www.hackerrank.com/challenges/kangaroo

# %%
#!/bin/python3

import math
import os
import random
import re
import sys

#
# Complete the 'kangaroo' function below.
#
# The function is expected to return a STRING.
# The function accepts following parameters:
#  1. INTEGER x1
#  2. INTEGER v1
#  3. INTEGER x2
#  4. INTEGER v2
#

def kangaroo(x1, v1, x2, v2):
    if v1 == v2:
        return("YES" if x1 == x2 else "NO")
    else:
        
        # 'jumps' is the number of steps such that
        # x1 + jumps * v1 = x2 + jumps * v2  
    
        # jumps % 1 == 0 checks if jumps is an integer and
        # jumps > 0 is needed for them to ever catch up
        
        jumps = (x1 - x2) / (v2 - v1) 
        
        return("YES" if jumps % 1 == 0 and jumps > 0 else "NO")

if __name__ == '__main__':
    fptr = open(os.environ['OUTPUT_PATH'], 'w')

    first_multiple_input = input().rstrip().split()

    x1 = int(first_multiple_input[0])

    v1 = int(first_multiple_input[1])

    x2 = int(first_multiple_input[2])

    v2 = int(first_multiple_input[3])

    result = kangaroo(x1, v1, x2, v2)

    fptr.write(result + '\n')

    fptr.close()

# %% [markdown]
# ### Viral Advertising
# https://www.hackerrank.com/challenges/strange-advertising

# %%
#!/bin/python3

import math
import os
import random
import re
import sys

#
# Complete the 'viralAdvertising' function below.
#
# The function is expected to return an INTEGER.
# The function accepts INTEGER n as parameter.
#

def viralAdvertising(n):
    # Write your code here
    
    # Starting values (day 1)
    starting_people = 5
    liked = starting_people // 2
    cumulative = liked

    # I could've put it all 
    # in a single 'cumulative += ...'
    # expression but written this way
    # you get a better picture of the
    # 'viral advertising strategy'
    for _ in range(1,n):   
        recipients = liked * 3
        liked = recipients // 2       
        cumulative += liked
    
    return(cumulative)

if __name__ == '__main__':
    fptr = open(os.environ['OUTPUT_PATH'], 'w')

    n = int(input().strip())

    result = viralAdvertising(n)

    fptr.write(str(result) + '\n')

    fptr.close()

# %% [markdown]
# ### Recursive Digit Sum
# https://www.hackerrank.com/challenges/recursive-digit-sum
#
# This solution fails test cases `6,7,8,9`, which all use huge numbers as inputs.
#
# I couldn't get the function to perform any better than in this solution, using recursion – as required by the challenge – and using `sum(map(int, n))` to sum up each digit of string `n` (I checked with `timeit` and on my machine it performed better than `for`, list comprehensions, `sum(int(x) for x in n)` and `reduce`).
#
# There is an alternative solution using the `%` operator but since it doesn't use recursion I wouldn't consider it.
#
# Since this challenge could be solved with several other programming languages too and the test cases stay the same, something faster like `C` would have been a better choice.
#
# Also, in `main` instead of calling `superDigit(n, k)` and adding in the function some code to make sure it used `n*k` only for the first time, I simply called `superDigit(n*k, k)`; since it's only supposed to be done the very first time, doing it within the function didn't make much sense to me.
#
# *Collaboration policy: I briefly discussed about this with Leonardo Lavagna.*

# %%
#!/bin/python3

import math
import os
import random
import re
import sys

#
# Complete the 'superDigit' function below.
#
# The function is expected to return an INTEGER.
# The function accepts following parameters:
#  1. STRING n
#  2. INTEGER k
#

def superDigit(n, k):
    # Write your code here
    if len(n) == 1:
        return(int(n))
    else:
        new_n = sum(map(int, n))
        return(superDigit(str(new_n), k))

if __name__ == '__main__':
    fptr = open(os.environ['OUTPUT_PATH'], 'w')

    first_multiple_input = input().rstrip().split()

    n = first_multiple_input[0]

    k = int(first_multiple_input[1])

    result = superDigit(n*k, k)

    fptr.write(str(result) + '\n')

    fptr.close()

# %% [markdown]
# ### Insertion Sort - Part 1
# https://www.hackerrank.com/challenges/insertionsort1/

# %%
#!/bin/python3

import math
import os
import random
import re
import sys

#
# Complete the 'insertionSort1' function below.
#
# The function accepts following parameters:
#  1. INTEGER n
#  2. INTEGER_ARRAY arr
#

def insertionSort1(n, arr):
    # Write your code here
    unsorted_value = arr[-1]
    
    for i in range(2, n+1):
        if arr[-i] <= unsorted_value:
            arr[-i+1] = unsorted_value
            break
        else:
            arr[-i+1] = arr[-i]
            print(*arr)
            if i == n:
                arr[0] = unsorted_value
    print(*arr)

if __name__ == '__main__':
    n = int(input().strip())

    arr = list(map(int, input().rstrip().split()))

    insertionSort1(n, arr)

# %% [markdown]
# ### Insertion Sort - Part 2
# https://www.hackerrank.com/challenges/insertionsort2

# %%
#!/bin/python3

import math
import os
import random
import re
import sys

#
# Complete the 'insertionSort2' function below.
#
# The function accepts following parameters:
#  1. INTEGER n
#  2. INTEGER_ARRAY arr
#

def insertionSort2(n, arr):
    # Write your code here
    for i in range(n):
        unsorted_value = arr[i]
        
        j = i
        while j > 0 and arr[j-1] > unsorted_value:
            arr[j] = arr[j-1]
            j = j-1
        arr[j] = unsorted_value
        
        if i > 0:
            print(*arr)
        

if __name__ == '__main__':
    n = int(input().strip())

    arr = list(map(int, input().rstrip().split()))

    insertionSort2(n, arr)
